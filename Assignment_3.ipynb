# %% [markdown]
# # Assignment: 3

# %% [markdown]
# 1. Why are functions advantageous to have in your programs?

# %% [markdown]
# Answer 1.
# A function is a reusable code block that is used to carry out a specific task.
# Advantageous:-
# Reducing code duplication, Taking big problems and breaking them down into smaller chunks, Increasing the code's clarity, Reusability of code, Concealing of information

# %% [markdown]
# 2. When does the code in a function run: when it's specified or when it's called?

# %% [markdown]
# Answer 2. A function is a collection of code that performs a certain task and can be called whenever it is called.

# %% [markdown]
# 3. What statement creates a function?

# %% [markdown]
# Answer 3. def is the keywords that is used to create the function.
#
# example: def print_my_name(a):
#                 print(a)

# %% [markdown]
# 4. What is the difference between a function and a function call?

# %% [markdown]
# Answer 4.The def keyword is used to define a function.
# example: def print_my_name(a):
#                 print(a)
# To call a function use the function name followed by parenthesis
# example: def print_my_name(a):
#                 print(a)
#         print_my_name("Mr. Coder")

# %% [markdown]
# 5. How many global scopes are there in a Python program? How many local scopes?

# %% [markdown]
# Answer 5. There’s only one global Python scope per program execution and one local scope.

# %% [markdown]
# 6. What happens to variables in a local scope when the function call returns?

# %% [markdown]
# Answer 6. When the execution of the function terminates (returns), the local variables are destroyed.

# %% [markdown]
# 7. What is the concept of a return value? Is it possible to have a return value in an expression?

# %% [markdown]
# Answer 7. A return value is the value that a function call evaluates to. Like any value, a return value can be used as part of an expression.

# %% [markdown]
# 8. If a function does not have a return statement, what is the return value of a call to that function?

# %% [markdown]
# Answer 8. If there is no return statement for a function, its return value is None.

# %% [markdown]
# 9. How do you make a function variable refer to the global variable?

# %% [markdown]
# Answer 9. A global statement will force a variable in a function to refer to the global variable.
# example: def print_my_name(a):
#             global x
#             x="hello"
#             print(a)

# %% [markdown]
# 10. What is the data type of None?

# %% [markdown]
# Answer 10. The data type of None is NoneType.

# %% [markdown]
# 11. What does the sentence import areallyourpetsnamederic do?

# %% [markdown]
# Answer 11.Error occurs: ModuleNotFoundError: No module named 'areallyourpetsnamederic'

# %% [markdown]
# 12. If you had a bacon() feature in a spam module, what would you call it after importing spam?

# %%
Answer 12. This function can be called with spam.bacon().

# %% [markdown]
# 13. What can you do to save a programme from crashing if it encounters an error?

# %%
Answer 13. Error handling can be used to notify the user of why the error occurred and gracefully exit the process that caused the error.

# %% [markdown]
# 14. What is the purpose of the try clause? What is the purpose of the except clause?

# %%
Answer 14. Except statement catches an exception. It is used to test code for an error which is written in the “try” statement. If an error is encountered, the contents of the “except” block are run.
