# %% [markdown]
# 1.What are the two values of the Boolean data type? How do you write them?

# %% [markdown]
# Answer 1. The boolean value can be of two types only. either True or False.
#
# Input:  var1 = 0
#         print(bool(var1))
# Output: False
#
# Input:  var2 = 1
#         print(bool(var2))
# Output: Ture

# %% [markdown]
# 2. What are the three different types of Boolean operators?

# %% [markdown]
# Answer 2. The three type of Boolean Operators are:
# 1.AND boolean operator
# 2.NOT boolean operator
# 3.OR boolean operator

# %% [markdown]
# 3. Make a list of each Boolean operator's truth tables (i.e. every possible combination of Boolean values for the operator and what it evaluate ).

# %% [raw]
# # Answer 3.
# == Truth Table
# x	==	y	Returns
# True	==	True	True
# True	==	False	False
# False	==	True	False
# False	==	False	True
#
# AND Truth Table
# x	and	y	Returns
# True	and	True	True
# True	and	False	False
# False	and	True	False
# False	and	False	False
#
# OR Truth Table
# x	or	y	Returns
# True	or	True	True
# True	or	False	True
# False	or	True	True
# False	or	False	False
#
# NOT Truth Table
# not	x	Returns
# not	True	False
# not	False	True
