# %% [markdown]
# # Assignment:-1

# %% [raw]
# 1. In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be mathematical operators.
# *
# 'hello'
# -87.8
# -
# /
# +
# 6

# %% [raw]
# Answer 1.
# *,-,/,+  are mathematical operators.
# 'hello'is string
# -87.8 is float
# 6 is integer

# %% [raw]
# 2. What is the difference between string and variable?

# %% [raw]
# Answer 2.
# A variable is something that holds a value that may change. Variable is a name that can refer to any value
# A 'string' is simply a list of characters in order. String is a value representing text

# %% [raw]
# 3. Describe three different data types.

# %% [raw]
# Answer 3.
# Numeric data type represent the data which has numeric value. Numeric value can be integer, floating number or even complex numbers. These values are defined as int, float and complex class in Python.
# Strings are arrays of bytes representing Unicode characters. A string is a collection of one or more characters put in a single quote, double-quote or triple quote. In python there is no character data type, a character is a string of length one. It is represented by str class.
# Dictionary in Python is an unordered collection of data values, used to store data values like a map, which unlike other Data Types that hold only single value as an element, Dictionary holds key:value pair. Key-value is provided in the dictionary to make it more optimized.

# %% [raw]
# 4. What is an expression made up of? What do all expressions do?

# %% [raw]
# Answer 4.
# An expression is a combination of operators and operands that is interpreted to produce some other value. In any programming language, an expression is evaluated as per the precedence of its operators. So that if there is more than one operator in an expression, their precedence decides which operation will be performed first.

# %% [raw]
# 5. This assignment statements, like spam = 10. What is the difference between an expression and a statement?

# %% [raw]
# Answer 5.
# An expression evaluates to a value. The evaluation of a statement does not changes state. Evaluation of an expression always Produces or returns a result value. Every expression can’t be a statement.
# example:>>> a + 16
# >>> 20
# A statement executes something. The execution of a statement changes state. Execution of a statement may or may not produces or displays a result value, it only does whatever the statement says. Every statement can be an expression.
# example:>>> spam = 10
# >>>print(spam)
# output: 10

# %% [raw]
# 6. After running the following code, what does the variable bacon contain?
# bacon = 22
# bacon + 1

# %% [raw]
# Answer 6.
# variable becon contain the 22 after running the code.

# %% [raw]
# 7. What should the values of the following two terms be?
# 'spam' + 'spamspam'
# 'spam' * 3

# %% [raw]
# Answer 7.
# 'spam' + 'spamspam' = 'spamspamspam'
# 'spam' * 3 = 'spamspamspam'

# %% [raw]
# 8. Why is eggs a valid variable name while 100 is invalid?

# %% [raw]
# Answer 8.
# 100 is an integer.100 is invalid because cannot assign to literal.

# %% [raw]
# 9. What three functions can be used to get the integer, floating-point number, or string version of a value?

# %% [raw]
# Answer 9.
# The int() , float() , and str( ) functions will evaluate to the integer, floating-point number, and string versions of the value passed to them

# %% [raw]
# 10. Why does this expression cause an error? How can you fix it?
# 'I have eaten ' + 99 + ' burritos.'

# %% [raw]
# Answer 10.
# 'I have eaten ' + "99" + ' burritos.'
